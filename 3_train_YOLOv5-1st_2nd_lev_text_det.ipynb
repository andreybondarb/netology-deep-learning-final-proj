# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %%
import torch
from IPython.display import Image, clear_output
import os
os.chdir('/drive/My Drive/Colab_Notebooks')

# %%
#clone YOLOv5 and
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
#%pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# /drive/My Drive/Colab_Notebooks/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.1 MB/s eta 0:00:00
# Setup complete. Using torch 1.13.1+cu116 (Tesla T4)

# %%
import os
os.chdir('/')

# %%
# !unzip -qo '/drive/My Drive/Colab_Notebooks/datasets/document_detection_2nd_level.zip'

# %%
os.chdir('/drive/My Drive/Colab_Notebooks/yolov5')

# %%
#Javascript сниппет для colab (обучение без прерывания)
# %%javascript
function ClickConnect(){
console.log("Working");
document.querySelector("colab-toolbar-button#connect").click()
}setInterval(ClickConnect,60000)

# %%
#Yolov5-large-2nd_level_det
# !python train.py --img 640 --batch 16 --epochs 1000  --data data/rosim_2nd_lev_text_det.yaml --weights 'runs/train/yolov5l_scene_13k_158k_570_test_8_bs_with_paragraphs_last/weights/best.pt'  --cfg models/yolov5l.yaml --patience 30 --name yolov5l_2st_level_rosim
# Out:
# train: weights=runs/train/yolov5l_scene_13k_158k_570_test_8_bs_with_paragraphs_last/weights/best.pt, cfg=models/yolov5l.yaml, data=data/rosim_2nd_lev_text_det.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5l_2st_level_rosim, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=30, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# fatal: cannot change to '/drive/My': No such file or directory
# YOLOv5 🚀 2022-12-13 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
#Yolov5-large-1st_level_det
# !python train.py --img 640 --batch 16 --epochs 1000  --data data/scene_text_rec_rosim.yaml --weights 'pretrained/yolov5m.pt' --cfg models/yolov5m.yaml --patience 30 --name yolov5m_scene_rosim
# Out:
# train: weights=pretrained/yolov5m.pt, cfg=models/yolov5m.yaml, data=data/scene_text_rec_rosim.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5m_scene_rosim, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=30, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 495 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-246-g2dd3db00 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...
